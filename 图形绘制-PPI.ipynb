# %%
import matplotlib.pyplot as plt
# https://blog.csdn.net/slamdunkofkd/article/details/123755099

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['figure.figsize'] = (12.8, 7.2)
## 分辨率 1500*1200
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 10}
plt.rc('font', **font)

# =====================================================
x = ['GCN', 'SAGE', 'GAT', 'GraphUNet', 'GCNII', 'CRF-linear', 'CRF-GCN', 'CRF-GraphSAGE', 'CRF-GAT', 'CRF-GCNII',
     'INC-MGS-GCN', 'INC-MGS-GAT', 'INC-MGS-SAGE', 'INC-MGS-GCNII']  #点的横坐标
k1 = [76.62,81.02,77.49,77.17,80.99,65.33,76.33,77.43,76.50,79.98,79.58,82.18,83.68,83.32]
k2 = [77.48,84.13,81.35,78.22,84.81,67.20,76.27,77.25,76.76,81.73,78.82,85.08,85.26,85.84]
k3=  [80.43,95.34,96.14,83.15,97.53,69.72,77.08,77.65,74.58,92.11,83.56,97.66,96.30,97.73]



ax1 = plt.subplot(1, 2, 1)

# 隐藏边框
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax1.plot(x, k1, 's-', color='lightsteelblue', label="PPI-1")  #s-:方形
ax1.plot(x, k2, 'o-', color='thistle', label="PPI-2")  #s-:方形
ax1.plot(x, k3, 'D-', color='lightskyblue', label="PPI-10")  #s-:方形
plt.ylabel("Accuracy(%)", fontsize=12)  #横坐标名字
plt.xticks(x, fontsize=12, rotation=90)
ax1.legend(loc="best", fontsize=12)  #图例
# =========================================================
x = ['GCN', 'SAGE', 'GAT', 'GraphUNet', 'GCNII', 'CRF-linear', 'CRF-GCN', 'CRF-GraphSAGE', 'CRF-GAT', 'CRF-GCNII',
     'INC-MGS-GCN', 'INC-MGS-GAT', 'INC-MGS-SAGE', 'INC-MGS-GCNII']  #点的横坐标
k1 = [54.55,67.30,60.72,55.54,65.79,48.30,50.79,54.57,52.95,61.22,55.32,65.12,68.76,67.92]
k2 = [56.10,72.93,68.55,59.12,74.54,49.45,49.47,53.48,55.01,66.37,55.63,73.42,74.20,75.32]
k3 = [62.48,92.18,93.53,68.70,95.86,50.17,52.36,54.44,54.98,87.10,62.16,94.81,92.19,95.57]

ax1 = plt.subplot(1, 2, 2)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax1.plot(x, k1, 's-', color='lightsteelblue', label="PPI-1")  #s-:方形
ax1.plot(x, k2, 'o-', color='thistle', label="PPI-2")  #s-:方形
ax1.plot(x, k3, 'D-', color='lightskyblue', label="PPI-10")  #s-:方形
plt.ylabel("Micro-F1(%)", fontsize=12)  #横坐标名字
plt.xticks(x, fontsize=12, rotation=90)
ax1.legend(loc="best", fontsize=12)
#图例
plt.tight_layout()  # 使子图适应作图区域避免坐标轴标签信息显示混乱
# ============================= 保存
plt.savefig("PPI.svg", dpi=300)
