# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt



plt.title("Pubmed")
plt.plot(x,k1,'s-',color = 'salmon',label="BaseLine")#s-:方形
plt.plot(x,k2,'o-',color = 'skyblue',label="MGC-GNNS")#o-:圆形
plt.xlabel("Model",fontsize=15)#横坐标名字
plt.ylabel("Accuracy(%)",fontsize=15)#横坐标名字
plt.yticks([45,50,55,60,65,70,75,80],fontsize=12)
plt.xticks(['GCN','SAGE','GAT','GraphUNet','GCNII'],fontsize=12)
plt.legend(loc = "best")#图例

# ============================================================
fig, ax=plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15}
plt.rc('font', **font)

plt.title("Citeseer")
plt.plot(x,k1,'s-',color = 'salmon',label="BaseLine")#s-:方形
plt.plot(x,k2,'o-',color = 'skyblue',label="MGC-GNNS")#o-:圆形
plt.xlabel("Model",fontsize=15)#横坐标名字
plt.ylabel("Accuracy(%)",fontsize=15)#横坐标名字
plt.yticks([45,50,55,60,65,70,75,80],fontsize=12)
plt.xticks(['GCN','SAGE','GAT','GraphUNet','GCNII'],fontsize=12)
plt.legend(loc = "best")#图例

# ==============================================================

fig, ax=plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
font = {'family': 'serif',
        'serif': 'Times New Roman',
        'weight': 'normal',
        'size': 15}
plt.rc('font', **font)

plt.title("DBLP")
plt.plot(x,k1,'s-',color = 'salmon',label="BaseLine")#s-:方形
plt.plot(x,k2,'o-',color = 'skyblue',label="MGC-GNNS")#o-:圆形
plt.xlabel("Model",fontsize=15)#横坐标名字
plt.ylabel("Accuracy(%)",fontsize=15)#横坐标名字
plt.yticks([45,50,55,60,65,70,75,80],fontsize=12)
plt.xticks(['GCN','SAGE','GAT','GraphUNet','GCNII'],fontsize=12)
plt.legend(loc = "best")#图例

# ============================= 保存
plt.savefig("demo.pdf",dpi=300)
